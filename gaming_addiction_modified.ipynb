# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('online_gaming_behavior_dataset.csv')

# %%
data.head()
# Out:
#    PlayerID  Age  Gender Location GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43    Male    Other  Strategy      16.271119                0
# 1      9001   29  Female      USA  Strategy       5.525961                0
# 2      9002   22  Female      USA    Sports       8.223755                0
# 3      9003   35    Male      USA    Action       5.265351                1
# 4      9004   33    Male   Europe    Action      15.531945                0
#
#   GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0         Medium                6                        108           79
# 1         Medium                5                        144           11
# 2           Easy               16                        142           35
# 3           Easy                9                         85           57
# 4         Medium                2                        131           95
#
#    AchievementsUnlocked EngagementLevel
# ...

# %%
gender_engagement = data.groupby('Gender')['EngagementLevel'].value_counts().unstack()
gender_engagement.plot(kind='bar', figsize=(8, 5), color=['skyblue', 'orange', 'green'])
plt.title('Engagement Level by Gender')
plt.xlabel('Gender')
plt.xticks(rotation=0)
plt.ylabel('Number of Players')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define custom color palette
color=['skyblue', 'orange', 'green']

plt.figure(figsize=(10, 6))
sns.countplot(x='GameGenre', hue='EngagementLevel', data=data, palette=color)
plt.title('Count of Game Genre by Engagement Level')
plt.xlabel('Game Genre')
plt.ylabel('Count')
plt.show()

# %%
engagement_distribution = data.groupby(['GameDifficulty', 'EngagementLevel']).size().unstack()

# Plot the graph with separate bars
engagement_distribution.plot(kind='bar', color=['orange', 'green', 'lightblue'], figsize=(10, 6))
plt.title('Engagement Level Distribution by Game Difficulty')
plt.xlabel('Game Difficulty')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Engagement Level')
plt.show()

# %%
avg_playtime_gender = data.groupby(['GameGenre', 'Gender'])['PlayTimeHours'].mean().unstack()
avg_playtime_gender.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'orange'])
plt.title('Average Playtime by Game Genre and Gender')
plt.xlabel('Game Genre')
plt.ylabel('Average Playtime (Hours)')
plt.xticks(rotation=0)
plt.legend(title='Gender')
plt.show()

# %%
avg_sessions_genre_gender = data.groupby(['GameGenre', 'Gender'])['SessionsPerWeek'].mean().unstack()
avg_sessions_genre_gender.plot(kind='bar', figsize=(10, 6), color=['green', 'lightblue'])
plt.title('Average Sessions Per Week by Game Genre and Gender')
plt.xlabel('Game Genre')
plt.ylabel('Average Sessions Per Week')
plt.xticks(rotation=0)
plt.legend(title='Engagement Level')
plt.show()

# %%
avg_player_level_difficulty_engagement = data.groupby(['GameDifficulty', 'EngagementLevel'])['PlayerLevel'].mean().unstack()
avg_player_level_difficulty_engagement.plot(kind='bar', figsize=(10, 6), color=['lightblue', 'green', 'orange'])
plt.title('Average Player Level by Game Difficulty and Engagement Level')
plt.xlabel('Game Difficulty')
plt.ylabel('Average Player Level')
plt.xticks(rotation=0)
plt.legend(title='Engagement Level')
plt.show()

# %%
engagement_distribution_gender = data.groupby(['GameDifficulty', 'Gender', 'EngagementLevel']).size().unstack().unstack()

# Plotting the graph with separate bars
engagement_distribution_gender.plot(kind='bar', figsize=(12, 6), color=['lightblue', 'green', 'orange'])
plt.title('Engagement Level Distribution by Game Difficulty and Gender')
plt.xlabel('Game Difficulty and Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.legend(title='Engagement Level')
plt.show()

# %%
data.describe()
# Out:
#            PlayerID           Age  PlayTimeHours  InGamePurchases  \
# count  40034.000000  40034.000000   40034.000000     40034.000000
# mean   29016.500000     31.992531      12.024365         0.200854
# std    11556.964675     10.043227       6.914638         0.400644
# min     9000.000000     15.000000       0.000115         0.000000
# 25%    19008.250000     23.000000       6.067501         0.000000
# 50%    29016.500000     32.000000      12.008002         0.000000
# 75%    39024.750000     41.000000      17.963831         0.000000
# max    49033.000000     49.000000      23.999592         1.000000
#
#        SessionsPerWeek  AvgSessionDurationMinutes   PlayerLevel  \
# count     40034.000000               40034.000000  40034.000000
# mean          9.471774                  94.792252     49.655568
# std           5.763667                  49.011375     28.588379
# min           0.000000                  10.000000      1.000000
# ...

# %%
sum = data.groupby('EngagementLevel').sum()
print(sum)
# Out:
#                   PlayerID     Age  \
# EngagementLevel
# High             300062383  329926
# Low              300354246  329304
# Medium           561229932  621559
#
#                                                             Gender  \
# EngagementLevel
# High             FemaleFemaleMaleFemaleMaleMaleMaleFemaleMaleMa...
# Low              MaleMaleFemaleMaleMaleFemaleMaleFemaleFemaleFe...
# Medium           MaleFemaleMaleMaleFemaleFemaleFemaleFemaleFema...
#
#                                                           Location  \
# EngagementLevel
# High             USAOtherUSAAsiaUSAEuropeAsiaUSAEuropeEuropeUSA...
# Low              EuropeUSAUSAUSAUSAAsiaUSAUSAAsiaEuropeUSAUSAEu...
# Medium           OtherUSAUSAEuropeAsiaEuropeAsiaUSAUSAEuropeUSA...
#
#                                                          GameGenre  \
# EngagementLevel
# High             SportsSportsStrategySimulationSportsRPGStrateg...
# Low              RPGActionStrategySimulationRPGRPGSportsSportsS...
# ...

# %%
data.isnull().sum()
# Out:
# PlayerID                     0
# Age                          0
# Gender                       0
# Location                     0
# GameGenre                    0
# PlayTimeHours                0
# InGamePurchases              0
# GameDifficulty               0
# SessionsPerWeek              0
# AvgSessionDurationMinutes    0
# PlayerLevel                  0
# AchievementsUnlocked         0
# EngagementLevel              0
# dtype: int64

# %%
for col in ['Age', 'Gender','Location', 'GameGenre', 'PlayTimeHours',
       'InGamePurchases','GameDifficulty','SessionsPerWeek', 'AvgSessionDurationMinutes', 'PlayerLevel', 'AchievementsUnlocked','EngagementLevel']:
    print("-------------------------------")
    print(f'Column name: {col}\n')
    print(f'Unique values:\n{data[col].unique()}')
# Out:
# -------------------------------
# Column name: Age
#
# Unique values:
# [43 29 22 35 33 37 25 38 17 36 16 44 47 26 39 41 42 30 21 23 32 18 28 40
#  34 49 31 20 48 24 45 15 19 27 46]
# -------------------------------
# Column name: Gender
#
# Unique values:
# ['Male' 'Female']
# -------------------------------
# Column name: Location
#
# Unique values:
# ['Other' 'USA' 'Europe' 'Asia']
# -------------------------------
# Column name: GameGenre
#
# Unique values:
# ['Strategy' 'Sports' 'Action' 'RPG' 'Simulation']
# -------------------------------
# Column name: PlayTimeHours
#
# Unique values:
# [16.27111876  5.52596138  8.22375524 ...  0.24005688 14.01781798
#  10.08380358]
# -------------------------------
# Column name: InGamePurchases
#
# Unique values:
# [0 1]
# -------------------------------
# Column name: GameDifficulty
#
# Unique values:
# ['Medium' 'Easy' 'Hard']
# -------------------------------
# Column name: SessionsPerWeek
#
# Unique values:
# ...

# %%
plt.figure(figsize=(12, 8))
plt.bar(data['Gender'], data['EngagementLevel'], color='skyblue')  # Corrected syntax
plt.title('Bar Graph Example')
plt.xlabel('Age')
plt.ylabel('Engagement Level')
plt.show()

# %%
# Feature selection 
numerical_cols = ['Age','PlayTimeHours','SessionsPerWeek','AvgSessionDurationMinutes','PlayerLevel'] 

textual_cols = ['Gender','Location','GameGenre','GameDifficulty'] 

target_col = 'EngagementLevel'

# %%
# Separate features and target
X = data[numerical_cols + textual_cols]
y = data[target_col]

# %%
# Label Encoding 

from sklearn.preprocessing import LabelEncoder

# Assuming 'data' is your DataFrame and you want to encode multiple columns
label_encode = LabelEncoder()

data[target_col] = label_encode.fit_transform(data[target_col])

for col in textual_cols:
    data[col] = label_encode.fit_transform(data[col])

# %%
data.head()
# Out:
#    PlayerID  Age  Gender  Location  GameGenre  PlayTimeHours  InGamePurchases  \
# 0      9000   43       1         2          4      16.271119                0
# 1      9001   29       0         3          4       5.525961                0
# 2      9002   22       0         3          3       8.223755                0
# 3      9003   35       1         3          0       5.265351                1
# 4      9004   33       1         1          0      15.531945                0
#
#    GameDifficulty  SessionsPerWeek  AvgSessionDurationMinutes  PlayerLevel  \
# 0               2                6                        108           79
# 1               2                5                        144           11
# 2               0               16                        142           35
# 3               0                9                         85           57
# 4               2                2                        131           95
#
#    AchievementsUnlocked  EngagementLevel
# ...

# %%
#Standerd Scaling
from sklearn.preprocessing import StandardScaler

# Initialize StandardScaler
standard_scaler = StandardScaler()

# Apply StandardScaler to numerical columns
data[numerical_cols] = standard_scaler.fit_transform(data[numerical_cols])

# %%
data.head(10)
# Out:
#    PlayerID       Age  Gender  Location  GameGenre  PlayTimeHours  \
# 0      9000  1.096023       1         2          4       0.614176
# 1      9001 -0.297969       0         3          4      -0.939816
# 2      9002 -0.994965       0         3          3      -0.549654
# 3      9003  0.299456       1         3          0      -0.977506
# 4      9004  0.100314       1         1          0       0.507275
# 5      9005  0.498598       1         1          1       1.234713
# 6      9006 -0.696252       1         3          0      -0.328532
# 7      9007 -0.696252       0         0          1      -1.102405
# 8      9008  0.598169       0         1          2       0.886300
# 9      9009  0.598169       0         2          3       1.723670
#
#    InGamePurchases  GameDifficulty  SessionsPerWeek  \
# 0                0               2        -0.602363
# 1                0               2        -0.775865
# 2                0               0         1.132666
# ...

# %%
print(textual_cols)
print(numerical_cols)
print(target_col)
# Out:
# ['Gender', 'Location', 'GameGenre', 'GameDifficulty']
# ['Age', 'PlayTimeHours', 'SessionsPerWeek', 'AvgSessionDurationMinutes', 'PlayerLevel']
# EngagementLevel

# %%
# Separate features and target
X = data[numerical_cols + textual_cols]
y = data[target_col]

# %%
print(X)
print(y
)
# Out:
#             Age  PlayTimeHours  SessionsPerWeek  AvgSessionDurationMinutes  \
# 0      1.096023       0.614176        -0.602363                   0.269487
# 1     -0.297969      -0.939816        -0.775865                   1.004019
# 2     -0.994965      -0.549654         1.132666                   0.963212
# 3      0.299456      -0.977506        -0.081854                  -0.199798
# 4      0.100314       0.507275        -1.296374                   0.738771
# ...         ...            ...              ...                        ...
# 40029  0.000744       1.243074        -0.949368                  -0.403835
# 40030  1.195594       0.219091         1.653174                   0.391909
# 40031 -1.691961      -1.704277         0.091649                   1.656937
# 40032  0.199885       0.288298        -1.122871                   0.677560
# 40033 -1.293677      -0.280649         0.612157                  -0.220202
#
#        PlayerLevel  Gender  Location  GameGenre  GameDifficulty
# ...

# %%
#Spliting the data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
print(X_test)
# Out:
#             Age  PlayTimeHours  SessionsPerWeek  AvgSessionDurationMinutes  \
# 16798 -0.397540       1.388605         0.785660                  -1.485230
# 21379 -0.895394      -1.543423        -0.775865                  -0.648679
# 22004 -1.094536      -1.621890        -0.255357                  -1.383212
# 25619 -0.497111      -0.400723        -0.602363                   0.514331
# 33789 -0.895394       0.211011        -0.949368                  -1.383212
# ...         ...            ...              ...                        ...
# 16718 -0.497111       0.631125         1.653174                  -0.811908
# 28013  0.896881       1.468498        -0.255357                   0.351101
# 31610 -0.198398       1.220623        -0.428860                   0.024643
# 17146  0.697740       0.287235         0.438654                  -1.301597
# 37493  0.100314      -0.732128         0.438654                  -1.179175
#
#        PlayerLevel  Gender  Location  GameGenre  GameDifficulty
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)

# Train the model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Evalution of the model 
from sklearn.metrics import accuracy_score

preds = rf_model.predict(X_test)
print(accuracy_score(preds,y_test))
# Out:
# 0.8916974722749526

# %%
from sklearn.metrics import classification_report, accuracy_score

# Make predictions
y_pred = rf_model.predict(X_test)

# Evaluate the model
print(classification_report(y_test, y_pred))
print('Accuracy:', accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89      2534
#            1       0.88      0.85      0.86      2620
#            2       0.89      0.92      0.91      4855
#
#     accuracy                           0.89     10009
#    macro avg       0.89      0.88      0.89     10009
# weighted avg       0.89      0.89      0.89     10009
#
# Accuracy: 0.8916974722749526

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[2220   74  240]
#  [  74 2231  315]
#  [ 138  243 4474]]

# %%
print(preds)
# Out:
# [2 2 1 ... 2 2 2]

# %%
plt.figure(figsize=(8, 5))
plt.bar(data['Age'], data['EngagementLevel'], color='skyblue')  # Corrected syntax
plt.title('Bar Graph Example')
plt.xlabel('Age')
plt.ylabel('Engagement Level')
plt.show()

# %%
# Assume the preprocessing has been done already, so we have the LabelEncoder and StandardScaler fitted

# Example for user input handling
user_input = {}

# Collecting user input
user_input['age'] = int(input("Enter age: "))
user_input['playtime_hours'] = float(input("Enter playtime hours: "))
user_input['sessions_per_week'] = int(input("Enter sessions per week: "))
user_input['average_duration'] = float(input("Enter average duration of each session: "))
user_input['player_level'] = input("Enter player level (low, mid, high): ")

# Convert input to DataFrame
user_df = pd.DataFrame([user_input])

# Preprocess the input
user_df['player_level'] = label_encode.transform(user_df['player_level'])
user_df[numerical_cols] = standard_scaler.transform(user_df[numerical_cols])

# Store the preprocessed input for later use (optional, e.g., saving to a file or database)
user_df.to_csv('preprocessed_user_input.csv', index=False)

# Make prediction
user_prediction = rf_model.predict(user_df)

# Decode the prediction (if necessary)
predicted_engagement_level = label_encode.inverse_transform(user_prediction)
print('Predicted Engagement Level:', predicted_engagement_level[0])

# Optionally, store the prediction result
with open('predictions.txt', 'a') as f:
    f.write(f"User input: {user_input}, Predicted Engagement Level: {predicted_engagement_level[0]}\n")

# %%
# Function to get user input
def get_user_input():
    user_data = {}
    user_data['Age'] = int(input("What is your age? "))
    user_data['PlayTimeHours'] = float(input("How many hours do you play games per week? "))
    user_data['GameDifficulty'] = int(input("On a scale of 1 to 10, how difficult are the games you play? "))
    user_data['SessionsPerWeek'] = int(input("How many gaming sessions do you have per week? "))
    user_data['AvgSessionDurationMinutes'] = float(input("What is the average duration (in minutes) of your gaming sessions? "))
    user_data['PlayerLevel'] = int(input("What is your player level? "))
        
    # Assuming binary gender for simplicity, otherwise use a more complex encoding method
    gender = input("What is your gender? (Male/Female) ").lower()
    user_data['Gender_Male'] = 1 if gender == 'male' else 0
    
    # Assuming a predefined set of locations and game genres
    location = input("Where are you located? (e.g., US, UK, IN) ").upper()
    predefined_locations = ['US', 'UK', 'IN']  # Add other locations as per your dataset
    for loc in predefined_locations:
        user_data[f'Location_{loc}'] = 1 if location == loc else 0
    
    game_genre = input("What genre of games do you play? (e.g., Action, RPG, Puzzle) ").capitalize()
    predefined_genres = ['Action', 'RPG', 'Puzzle']  # Add other genres as per your dataset
    for genre in predefined_genres:
        user_data[f'GameGenre_{genre}'] = 1 if game_genre == genre else 0
    
    return user_data

# Get user input
new_user_data = get_user_input()

# %%
# Convert the input data to a dataframe
new_user_df = pd.DataFrame([new_user_data])

# %%
# Ensure all features are present
for col in X.columns:
    if col not in new_user_df:
        new_user_df[col] = 0  # Add missing columns with default value 0

# %%
# Reorder columns to match the training set
new_user_df = new_user_df[X.columns]

# %%
# Make prediction
new_user_prediction = rf_model.predict(new_user_df)
addiction_level = label_encode.inverse_transform(new_user_prediction)
print('Predicted Addiction Level:', addiction_level[0])
# Provide tips based on predictions
def provide_tips(addiction_level):
    if addiction_level == 'low':
        tips = "Your gaming habits seem balanced. Continue to enjoy gaming in moderation."
    elif addiction_level == 'mid':
        tips = "Consider monitoring your gaming habits and setting time limits to avoid potential addiction."
    elif addiction_level == 'high':
        tips = "It is important to take steps to reduce gaming time and seek help if needed. Consider engaging in other activities."
    return tips

print(provide_tips(addiction_level[0]))
# Out:
# Predicted Addiction Level: 0
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[87], line 15
#      12         tips = "It is important to take steps to reduce gaming time and seek help if needed. Consider engaging in other activities."
#      13     return tips
# ---> 15 print(provide_tips(addiction_level[0]))
#
# Cell In[87], line 13, in provide_tips(addiction_level)
#      11 elif addiction_level == 'high':
#      12     tips = "It is important to take steps to reduce gaming time and seek help if needed. Consider engaging in other activities."
# ---> 13 return tips
#
# UnboundLocalError: cannot access local variable 'tips' where it is not associated with a value
